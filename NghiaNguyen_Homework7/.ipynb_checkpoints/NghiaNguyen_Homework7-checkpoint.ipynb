# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro

# %% [markdown]
# # Data Exploration - Q1

# %%
# Solution 1
Q1 = pd.read_excel("First set of data.xlsx", sheet_name = "Q1")

"""
# Solution 2
sheets = pd.ExcelFile("First set of data.xlsx")
sheet_1 = sheets.parse(0)
"""
# Out:
# '\n# Solution 2\nsheets = pd.ExcelFile("First set of data.xlsx")\nsheet_1 = sheets.parse(0)\n'

# %% [markdown]
# ## Check statistics of each variable

# %%
print(Q1.info())
print()
Q1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S1      135 non-null    int64
#  1   S2      135 non-null    int64
#  2   S3      134 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 3.3 KB
# None
#                S1          S2          S3
# count  135.000000  135.000000  134.000000
# mean   383.548148  306.044444  349.716418
# std     54.910880   91.372117   49.351678
# min    241.000000 -270.000000  211.000000
# 25%    349.500000  256.500000  314.250000
# 50%    378.000000  341.000000  351.500000
# 75%    424.500000  370.000000  387.500000
# max    505.000000  394.000000  500.000000

# %% [markdown]
# ## Check distribution of each variable

# %%
# Create a figure and three subplots
fig, axes = plt.subplots(1,3, figsize=(15,5))

# Plot histogram for S1,S2,S3
sns.histplot(Q1["S1"], kde = True, ax = axes[0])
sns.histplot(Q1["S2"], kde = True, ax = axes[1])
sns.histplot(Q1["S3"], kde = True, ax = axes[2])

# Set titles for the subplots
axes[0].set_title('S1 Histogram')
axes[1].set_title('S2 Histogram')
axes[2].set_title('S3 Histogram')

plt.show()

# %% [markdown]
# ## Checking missing values and see distribution of each variable

# %%
missing_values = Q1.isnull().sum()
percentage_missing_values = (missing_values/len(Q1))*100
Check_missing_values = pd.concat([missing_values, percentage_missing_values], axis=1, keys= ['Missing values', '% Missing'])
print(Check_missing_values)
# Out:
#     Missing values  % Missing
# S1               0   0.000000
# S2               0   0.000000
# S3               1   0.740741

# %% [markdown]
# ## Imputation of missing values

# %%
# Find index of null values in dataframe
print(Q1[Q1['S3'].isnull()].index.tolist())

# Solution 1
m = Q1["S3"].mean()
Q1["S3"].fillna(m, inplace = True)

# Solution 2
# df = df.interpolate()
# Out:
# []

# %% [markdown]
# ## Boxplot

# %%
ax = Q1.plot(kind = "box", title = "Boxplot", showmeans=True)

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(Q1, inner = "quartile")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pairplot

# %%
pairplot = sns.pairplot(Q1)
pairplot.fig.suptitle('Pair plot', fontsize=18, y=1.02)
plt.show()

# %% [markdown]
# ## Joint plot

# %%
sns.jointplot(Q1)

# %%
sns.catplot(Q1)

# %%
sns.relplot(Q1)

# %% [markdown]
# ## Outliers Detection

# %%
Q1_ = Q1.quantile(0.25)
Q3_ = Q1.quantile(0.75)

IQR = Q3_ - Q1_
lower_bound = Q1_ - 1.5*IQR
upper_bound = Q3_ + 1.5*IQR

outliers_S1 = Q1[(Q1['S1'] < lower_bound['S1']) | (Q1['S1'] > upper_bound['S1'])]
outliers_S2 = Q1[(Q1['S2'] < lower_bound['S2']) | (Q1['S2'] > upper_bound['S2'])]
outliers_S3 = Q1[(Q1['S3'] < lower_bound['S3']) | (Q1['S3'] > upper_bound['S3'])]

print(pd.concat([lower_bound, upper_bound], axis=1, keys= ['Lower Bound', 'Upper Bound']))

print(pd.concat([outliers_S1, outliers_S2, outliers_S3], axis=0, keys= ['outliers_S1', 'outliers_S3', "outliers_S3"]))
# Out:
#     Lower Bound  Upper Bound
# S1       237.00       537.00
# S2        86.25       540.25
# S3       205.75       495.75
#                   S1   S2          S3
# outliers_S3 120  350 -270  349.716418
#             11   350  300  500.000000

# %% [markdown]
# ## Plot after dropping outliers

# %%
updated_Q1 = Q1.drop([11, 120])
updated_Q1.plot(kind = "box", title = "Box plot", showmeans = True)

plt.figure(figsize=(8, 6))
sns.violinplot(updated_Q1)
plt.show()

plt.figure(figsize=(8, 6))
sns.relplot(updated_Q1)
plt.show()

plt.figure(figsize=(8, 6))
sns.pairplot(updated_Q1)
plt.show()

# %% [markdown]
# ## Heatmap before and after drop outliers

# %%
# %% Heatmap
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(Q1.corr(),vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize': 18}, pad=12)

plt.figure(figsize=(16, 6))
heatmap_ = sns.heatmap(updated_Q1.corr(),vmin=-1, vmax=1, annot=True, cmap=sns.cubehelix_palette(as_cmap=True))

# %% [markdown]
# # Data Exploration - Q2

# %%
Q2 = pd.read_excel("First set of data.xlsx", sheet_name = "Q2")
missing_values_Q2 = Q2.isnull().sum().sort_values(ascending=False)
percentage_missing_values_Q2 = (missing_values_Q2/len(Q2))*100
Check_missing_values_Q2 = pd.concat([missing_values_Q2, percentage_missing_values_Q2], axis=1, keys= ['Missing values', '% Missing'])
print(Check_missing_values_Q2)

sns.pairplot(Q2)

boxplot_Q2 = Q2.plot(kind = "box", title = "Boxplot", showmeans=True)
# Out:
#     Missing values  % Missing
# S1               0        0.0
# S2               0        0.0
# S3               0        0.0

# %%
sns.violinplot(Q2)
# Out:
# <AxesSubplot:>

# %%
heatmap_Q2 = sns.heatmap(Q2.corr(),vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap_Q2.set_title('Correlation Heatmap', fontdict={'fontsize': 18}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# # Data exploration - Q3

# %%
Q3 = pd.read_excel("First set of data.xlsx", sheet_name = "Q3")
Q3.describe()
missing_values_Q3 = Q3.isnull().sum().sort_values(ascending=False)
percentage_missing_values_Q3 = (missing_values_Q3/len(Q2))*100
Check_missing_values_Q3 = pd.concat([missing_values_Q3, percentage_missing_values_Q3], axis=1, keys= ['Missing values', '% Missing'])
print(Check_missing_values_Q3)

sns.pairplot(Q3)
boxplot = Q3.plot(kind = "box", title = "Box plot", showmeans = True)
# Out:
#     Missing values  % Missing
# S1               0        0.0
# S2               0        0.0
# S3               0        0.0

# %%
sns.jointplot(Q3)

# %%
sns.violinplot(Q3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Heatmap before and after drop outliers

# %%
heatmap_Q3 = sns.heatmap(Q3.corr(), vmin = -1, vmax = 1, annot = True, cmap = "BrBG")
heatmap_Q3.set_title("Correlation Heatmap", fontdict = {"fontsize":18}, pad = 12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# # Data exploration - Q4

# %%
"""
Boolean values, such as "TRUE" and "FALSE", are represented as True and False in Python, 
which correspond to the integer values 1 and 0, respectively. 
When reading the Excel file, pandas converts the boolean values to their corresponding integer representations.
"""

# Load dataset sheet Q4
Q4 = pd.read_excel("First set of data.xlsx", sheet_name = "Q4")

print(Q4.info())
print()
print(Q4.describe())
print()

# determine whether a column/variable is numeric or not in
is_number = np.vectorize(lambda x: np.issubdtype(x, np.number))
print(is_number(Q4.dtypes))


# Find exact location of non-numeric data
print(Q4[~Q4.applymap(np.isreal).all(1)])

# Edit data
Q4.at[98, "S3"] = 364

# Transform the whole column into numeric data
Q4 = Q4.apply(pd.to_numeric, errors="coerce")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S1      99 non-null     int64
#  1   S2      99 non-null     int64
#  2   S3      99 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 2.4+ KB
# None
#
#                S1          S2
# count   99.000000   99.000000
# mean   358.202020  213.818182
# std     45.137427   67.229938
# min    231.000000    0.000000
# 25%    334.500000  170.000000
# 50%    364.000000  200.000000
# 75%    391.000000  261.000000
# max    472.000000  381.000000
#
# [ True  True False]
#      S1   S2    S3
# 98  371  179  364'

# %% [markdown]
# ## Imputation of missing values

# %%
Missing_values_Q4 = Q4.isnull().sum().sort_values(ascending = False)
Percentage_missing_values_Q4 = Missing_values_Q4/len(Q4)*100
Check_missing_values_Q4 = pd.concat([Missing_values_Q4, Percentage_missing_values_Q4], axis=1, keys= ['Missing values', '% Missing'])
print(Check_missing_values_Q4)
# Out:
#     Missing values  % Missing
# S1               0        0.0
# S2               0        0.0
# S3               0        0.0

# %%
sns.violinplot(Q4)
# Out:
# <AxesSubplot:>

# %%
Q4.plot(kind = "box", title = "Box plot", showmeans =True)
# Out:
# <AxesSubplot:title={'center':'Box plot'}>

# %% [markdown]
# ## Outliers Detection

# %%
Q1_ = Q4.quantile(0.25)
Q3_ = Q4.quantile(0.75)
IQR_ = Q3_ - Q1_

lower_bound = Q1_ - 1.5 * IQR_
upper_bound = Q3_ + 1.5 * IQR_

outliers_S1 = Q4[(Q4['S1'] < lower_bound['S1']) | (Q4['S1'] > upper_bound['S1'])]
outliers_S2 = Q4[(Q4['S2'] < lower_bound['S2']) | (Q4['S2'] > upper_bound['S2'])]
outliers_S3 = Q4[(Q4['S3'] < lower_bound['S3']) | (Q4['S3'] > upper_bound['S3'])]

print(pd.concat([lower_bound, upper_bound], axis=1, keys= ['Lower Bound', 'Upper Bound']))

print(pd.concat([outliers_S1, outliers_S2, outliers_S3], axis=0, keys= ['outliers_S1', 'outliers_S3', "outliers_S3"]))
# Out:
#     Lower Bound  Upper Bound
# S1       249.75       475.75
# S2        33.50       397.50
# S3       314.75       412.75
#                  S1   S2   S3
# outliers_S1 28  247  174  351
#             31  236  301  352
#             56  231  311  364
# outliers_S3 19  279    0  372
#             20  392  197  311
#             59  365  172  285
#             60  285  157  311
#             64  472  151  285
#             70  405  231  262
#             72  397  201  236
#             73  331  282  208
#             87  443  149  302
#             90  395  165  261
#             91  307  181  256

# %% [markdown]
# ## Plot after drop outliers

# %%
outlier_indices = pd.concat([outliers_S1, outliers_S2, outliers_S3]).index
update_Q4 = Q4.drop(outlier_indices)
plt.figure(figsize=(8, 6))
update_Q4.plot(kind = "box", title = "Box Plot", showmeans = True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(update_Q4)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.relplot(update_Q4)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.pairplot(update_Q4)
plt.show()

# %% [markdown]
# ## Heatmap before and after drop outliers

# %%
heatmap_Q4 = sns.heatmap(Q4.corr(), vmin = -1, vmax = 1, annot = True, cmap = "BrBG")
heatmap_Q4.set_title("Heatmap Correlation", fontdict = {"fontsize":18}, pad = 12)
plt.show()

heatmap_Q4_ = sns.heatmap(update_Q4.corr(), vmin = -1, vmax = 1, annot = True, cmap = sns.cubehelix_palette(as_cmap=True))
plt.show()

# %% [markdown]
# # Data exploration - Q5

# %%
"""
Boolean values, such as "TRUE" and "FALSE", are represented as True and False in Python, 
which correspond to the integer values 1 and 0, respectively. 
When reading the Excel file, pandas converts the boolean values to their corresponding integer representations.
"""

# Load dataset sheet Q5
Q5 = pd.read_excel("First set of data.xlsx", sheet_name = "Q5")

print(Q5.info())
print()
print(Q5.describe())
print()

# determine whether a column/variable is numeric or not in
is_number = np.vectorize(lambda x: np.issubdtype(x, np.number))
print(is_number(Q5.dtypes))


# Find exact location of non-numeric data
print(Q5[~Q5.applymap(np.isreal).all(1)])

# Edit data
Q5.at[142, "S1"] = 425

# Transform the whole column into numeric data
Q5 = Q5.apply(pd.to_numeric, errors="coerce")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S1      147 non-null    object
#  1   S2      149 non-null    int64
#  2   S3      149 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.6+ KB
# None
#
#                S2           S3
# count  149.000000   149.000000
# mean   249.865772   404.791946
# std     74.649149   307.937631
# min    102.000000     1.000000
# 25%    190.000000   364.000000
# 50%    252.000000   384.000000
# 75%    301.000000   405.000000
# max    387.000000  4100.000000
#
# [False  True  True]
#        S1   S2   S3
# 142  425'  274  383

# %% [markdown]
# ## Normality check

# %%
def Normality_test(data):
    alpha = 0.5
    stat, p = shapiro(data)
    if p > alpha:
        return True
    return False

Normality_test(Q5["S3"])
# Out:
# False

# %% [markdown]
# ## Imputation of missing values

# %%
missing_values_Q5 = Q5.isnull().sum().sort_values(ascending = False)
percentage_missing_values_Q5 = missing_values_Q5/len(Q5)*100
check_missing_values_Q5 = pd.concat([missing_values_Q5, percentage_missing_values_Q5], axis = 1, keys= ['Missing values', '% Missing'])
print(check_missing_values_Q5)
print()

# Locate the index of null values
print("Index of null-value is:")
print(Q5[Q5['S1'].isnull()].index.tolist())
print()


Q5 = Q5.interpolate(method = "linear")
print(Q5.isnull().sum())
# Out:
#     Missing values  % Missing
# S1               2   1.342282
# S2               0   0.000000
# S3               0   0.000000
#
# Index of null-value is:
# [9, 25]
#
# S1    0
# S2    0
# S3    0
# dtype: int64

# %%
sns.pairplot(Q5)

# %%
Q5.plot(kind = "box", title = "Box Plot", showmeans = True)
# Out:
# <AxesSubplot:title={'center':'Box Plot'}>

# %%
sns.violinplot(Q5)
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
sns.histplot(Q5["S1"], kde = True, ax = axes[0])
sns.histplot(Q5["S2"], kde = True, ax = axes[1])
sns.histplot(Q5["S3"], kde = True, ax = axes[2])
axes[0].set_title('S1 Histogram')
axes[1].set_title('S2 Histogram')
axes[2].set_title('S3 Histogram')
plt.show()

# %% [markdown]
# ## Outliers Detection

# %%
Q1_ = Q5.quantile(0.25)
Q3_ = Q5.quantile(0.75)
IQR_ = Q3_ - Q1_

lower_bound = Q1_ - 1.5 * IQR_
upper_bound = Q3_ + 1.5 * IQR_

outliers_S1 = Q5[(Q5['S1'] < lower_bound['S1']) | (Q5['S1'] > upper_bound['S1'])]
outliers_S2 = Q5[(Q5['S2'] < lower_bound['S2']) | (Q5['S2'] > upper_bound['S2'])]
outliers_S3 = Q5[(Q5['S3'] < lower_bound['S3']) | (Q5['S3'] > upper_bound['S3'])]

print(pd.concat([lower_bound, upper_bound], axis=1, keys= ['Lower Bound', 'Upper Bound']))

print(pd.concat([outliers_S1, outliers_S2, outliers_S3], axis=0, keys= ['outliers_S1', 'outliers_S3', "outliers_S3"]))
# Out:
#     Lower Bound  Upper Bound
# S1        263.5        539.5
# S2         23.5        467.5
# S3        302.5        466.5
#                     S1   S2    S3
# outliers_S1 3    263.0  131   362
#             6    262.0  179   368
#             36   247.0  102   289
#             76   548.0  387   425
# outliers_S3 9    323.5  220     1
#             11   337.0  150   272
#             36   247.0  102   289
#             66   400.0  162   293
#             130  485.0  383  4100
#             133  451.0  257   255

# %% [markdown]
# ## Plot after drop outliers

# %%
outlier_indices = pd.concat([outliers_S1, outliers_S2, outliers_S3]).index
update_Q5 = Q5.drop(outlier_indices)
plt.figure(figsize=(8, 6))
update_Q5.plot(kind = "box", title = "Box Plot", showmeans = True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(update_Q5)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.relplot(update_Q5)
plt.show()

# %% [markdown]
# ## Heatmap before and after dropping outliers

# %%
heatmap_Q5 = sns.heatmap(Q5.corr(), vmin = -1, vmax = 1, annot = True, cmap = "BrBG")
heatmap_Q5.set_title("Heatmap Correlation", fontdict = {"fontsize":18}, pad = 12)
plt.show()

heatmap_Q5_ = sns.heatmap(update_Q5.corr(), vmin = -1, vmax = 1, annot = True, cmap = sns.cubehelix_palette(as_cmap=True))
plt.show()
