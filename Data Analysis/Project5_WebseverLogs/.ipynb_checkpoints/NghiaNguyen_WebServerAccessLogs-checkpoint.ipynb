# %% [markdown]
# ####    1.  [Webserver logs](https://www.kaggle.com/datasets/eliasdabbas/web-server-access-logs)
#
# ### About Dataset
# - Context
# Web sever logs contain information on any event that was registered/logged. This contains a lot of insights on website visitors, behavior, crawlers accessing the site, business insights, security issues, and more.
#
# - This is a dataset for trying to gain insights from such a file.
#
# - Content
# 3.3GB of logs from an Iranian ecommerce website zanbil.ir.
#
# - Acknowledgements
# Zaker, Farzin, 2019, "Online Shopping Store - Web Server Logs", https://doi.org/10.7910/DVN/3QBYB5, Harvard Dataverse, V1
#
# #### Features of the dataset
# - IP Address: The IP address of the client who made the request.
# - Timestamp: The date and time when the request was made.
# - HTTP Method: The HTTP method used for the request (e.g., GET, POST, etc.).
# - Request URL: The URL or path requested by the client.
# - HTTP Protocol: The version of the HTTP protocol used for the request (e.g., HTTP/1.1).
# - Response Code: The HTTP response code returned by the server (e.g., 200 for successful response).
# - Response Size: The size of the response in bytes.
# - User-Agent: The user agent string sent by the client's browser or application.
# - Referrer Information: Information about the referring page or source that led to the request.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import re
import json
import ijson

from scipy.stats import shapiro
from scipy import stats
import math
from scipy.stats import ttest_ind
from sklearn import preprocessing

# %% [markdown]
# # Load csv dataset

# %%
df = pd.read_csv("client_hostname.csv")
df.head(20)
# Out:
#              client                         hostname  \
# 0      5.123.144.95                     5.123.144.95
# 1      5.122.76.187                     5.122.76.187
# 2      5.215.249.99                     5.215.249.99
# 3     31.56.102.211          31-56-102-211.shatel.ir
# 4     5.123.166.223                    5.123.166.223
# 5       5.160.26.98                      5.160.26.98
# 6     5.127.147.132                    5.127.147.132
# 7     158.58.30.218                    158.58.30.218
# 8      86.55.230.86                     86.55.230.86
# 9      89.35.65.186                     89.35.65.186
# 10    5.120.208.157                    5.120.208.157
# 11     192.15.193.5                     192.15.193.5
# 12     46.41.210.95                     46.41.210.95
# 13  188.158.178.115  adsl-188-158-178-115.sabanet.ir
# 14    5.211.205.186                    5.211.205.186
# 15    5.122.221.229                    5.122.221.229
# 16     5.112.87.152                     5.112.87.152
# 17     5.214.59.242                     5.214.59.242
# 18     5.121.39.243                     5.121.39.243
# 19     5.124.223.22                     5.124.223.22
#
#                           alias_list         address_list
# 0             [Errno 1] Unknown host                  NaN
# 1             [Errno 1] Unknown host                  NaN
# 2             [Errno 1] Unknown host                  NaN
# 3     ['211.102.56.31.in-addr.arpa']    ['31.56.102.211']
# 4             [Errno 1] Unknown host                  NaN
# 5             [Errno 1] Unknown host                  NaN
# 6             [Errno 1] Unknown host                  NaN
# 7             [Errno 1] Unknown host                  NaN
# 8             [Errno 1] Unknown host                  NaN
# 9             [Errno 1] Unknown host                  NaN
# 10            [Errno 1] Unknown host                  NaN
# 11            [Errno 1] Unknown host                  NaN
# 12            [Errno 1] Unknown host                  NaN
# 13  ['115.178.158.188.in-addr.arpa']  ['188.158.178.115']
# 14            [Errno 1] Unknown host                  NaN
# 15            [Errno 1] Unknown host                  NaN
# 16            [Errno 1] Unknown host                  NaN
# 17            [Errno 1] Unknown host                  NaN
# 18            [Errno 1] Unknown host                  NaN
# 19            [Errno 1] Unknown host                  NaN

# %% [markdown]
# # Descriptive statistics

# %% [markdown]
# ### Building Summary of train data

# %%
df.describe()
# Out:
#               client                             hostname  \
# count         258445                               258441
# unique        258445                               258273
# top     5.123.144.95  int0.client.access.fanaptelecom.net
# freq               1                                  101
#
#                     alias_list       address_list
# count                   258445               5819
# unique                    5820               5819
# top     [Errno 1] Unknown host  ['31.56.102.211']
# freq                    252626                  1

# %%
# Reading the access.log file
with open('access.log', 'r') as file:
    log_entries = file.readlines()

# List to store the parsed log entries
parsed_entries = []

# Iterate over each log entry
for log_entry in log_entries:
    # Split the log entry by space
    split_entry = log_entry.split()

    # Ensure the split_entry has enough elements
    if len(split_entry) >= 14:
        # Extracting columns
        ip_address = split_entry[0]        
        timestamp = split_entry[3][1:] + ' ' + split_entry[4][:-1]        
        http_method = split_entry[5][1:]      
        request_url = split_entry[6]  
        http_protocol = split_entry[7][:-1]      
        response_code = split_entry[8]     
        response_size = split_entry[9]      
        user_agent = split_entry[11][1:-1]
        referrer = split_entry[13][1:-1]

        # Creating a dictionary for the log entry
        entry_dict = {
            'IP Address': ip_address,
            'Timestamp': timestamp,
            'HTTP Method': http_method,
            'Request URL': request_url,
            'HTTP Protocol': http_protocol,
            'Response Code': response_code,
            'Response Size': response_size,
            'User-Agent': user_agent,
            'Referrer Information': referrer
        }

        # Appending the dictionary to the list
        parsed_entries.append(entry_dict)

# the parsed entries to access.json file
with open('access.json', 'w') as file:
    json.dump(parsed_entries, file, indent=4)

# %%
def read_json_chunks(file_path, chunk_size):
    with open(file_path, 'r') as file:
        objects = ijson.items(file, 'item')
        chunk = []

        for i, obj in enumerate(objects):
            chunk.append(obj)
            if i + 1 == chunk_size:
                # When the number of objects in the chunk list reaches the specified chunk_size, 
                # the yield statement is used to yield the chunk.
                # This allows the caller to process the chunk while the function continues to read and yield subsequent chunks.
                yield chunk
                chunk = []

        if chunk:
            yield chunk

# %%
chunk_size = 10000
file_path = 'access.json'

access_df = pd.DataFrame()

for chunk in read_json_chunks(file_path, chunk_size):
    chunk_df = pd.DataFrame(chunk)
    access_df = pd.concat([access_df, chunk_df], ignore_index=True)

access_df
# Out:
#               IP Address                   Timestamp HTTP Method  \
# 0           54.36.149.41  22/Jan/2019:03:56:14 +0330         GET
# 1            31.56.96.51  22/Jan/2019:03:56:16 +0330         GET
# 2            31.56.96.51  22/Jan/2019:03:56:16 +0330         GET
# 3          40.77.167.129  22/Jan/2019:03:56:17 +0330         GET
# 4            91.99.72.15  22/Jan/2019:03:56:17 +0330         GET
# ...                  ...                         ...         ...
# 10186122   188.229.21.56  26/Jan/2019:20:29:13 +0330         GET
# 10186123    5.127.220.71  26/Jan/2019:20:29:13 +0330         GET
# 10186124      5.213.7.50  26/Jan/2019:20:29:13 +0330         GET
# 10186125  109.125.169.52  26/Jan/2019:20:29:13 +0330         GET
# 10186126   37.129.59.160  26/Jan/2019:20:29:13 +0330         GET
#
#                                                 Request URL HTTP Protocol  \
# 0         /filter/27|13%20%D9%85%DA%AF%D8%A7%D9%BE%DB%8C...      HTTP/1.1
# 1                         /image/60844/productModel/200x200      HTTP/1.1
# 2                         /image/61474/productModel/200x200      HTTP/1.1
# 3                         /image/14925/productModel/100x100      HTTP/1.1
# 4         /product/31893/62100/%D8%B3%D8%B4%D9%88%D8%A7%...      HTTP/1.1
# ...                                                     ...           ...
# 10186122                        /content/view/shoppingRules      HTTP/1.1
# 10186123                      /apple-touch-icon-120x120.png      HTTP/1.1
# 10186124  /m/product/18962/%D8%BA%D8%B0%D8%A7-%D8%B3%D8%...      HTTP/1.1
# 10186125  /image/%7B%7BbasketItem.id%7D%7D?type=productM...      HTTP/1.1
# 10186126                                       /basket/view      HTTP/1.1
#
#          Response Code Response Size         User-Agent Referrer Information
# 0                  200         30577         Mozilla/5.         hrefsBot/6.1
# 1                  200          5667         Mozilla/5.                ndroi
# 2                  200          5379         Mozilla/5.                ndroi
# 3                  200          1696         Mozilla/5.           ingbot/2.0
# 4                  200         41483         Mozilla/5.
# ...                ...           ...                ...                  ...
# 10186122           302             0         Mozilla/5.                ndroi
# 10186123           404         32420  MobileSafari/604.         arwin/18.2.0
# 10186124           200         20959         Mozilla/5.                    P
# 10186125           200             5         Mozilla/5.
# 10186126           200         17299         Mozilla/5.                ndroi
#
# [10186127 rows x 9 columns]

# %%
access_df['IP Address'] = access_df['IP Address'].astype('category')
access_df['Timestamp'] = pd.to_datetime(access_df['Timestamp'], format='%d/%b/%Y:%H:%M:%S %z')
access_df['HTTP Method'] = access_df['HTTP Method'].astype('category')
access_df['Response Code'] = pd.to_numeric(access_df['Response Code'], errors='coerce').astype('Int32')
access_df['Response Size'] = pd.to_numeric(access_df['Response Size'], errors='coerce').astype('Int32')
access_df['User-Agent'] = access_df['User-Agent'].astype('category')

col_names = ['IP Address','Timestamp','HTTP Method','Response Code','Response Size','User-Agent']
logs_df = access_df[col_names]
logs_df
# Out:
#               IP Address                 Timestamp HTTP Method  Response Code  \
# 0           54.36.149.41 2019-01-22 03:56:14+03:30         GET            200
# 1            31.56.96.51 2019-01-22 03:56:16+03:30         GET            200
# 2            31.56.96.51 2019-01-22 03:56:16+03:30         GET            200
# 3          40.77.167.129 2019-01-22 03:56:17+03:30         GET            200
# 4            91.99.72.15 2019-01-22 03:56:17+03:30         GET            200
# ...                  ...                       ...         ...            ...
# 10186122   188.229.21.56 2019-01-26 20:29:13+03:30         GET            302
# 10186123    5.127.220.71 2019-01-26 20:29:13+03:30         GET            404
# 10186124      5.213.7.50 2019-01-26 20:29:13+03:30         GET            200
# 10186125  109.125.169.52 2019-01-26 20:29:13+03:30         GET            200
# 10186126   37.129.59.160 2019-01-26 20:29:13+03:30         GET            200
#
#           Response Size         User-Agent
# 0                 30577         Mozilla/5.
# 1                  5667         Mozilla/5.
# 2                  5379         Mozilla/5.
# 3                  1696         Mozilla/5.
# 4                 41483         Mozilla/5.
# ...                 ...                ...
# 10186122              0         Mozilla/5.
# 10186123          32420  MobileSafari/604.
# 10186124          20959         Mozilla/5.
# 10186125              5         Mozilla/5.
# 10186126          17299         Mozilla/5.
#
# [10186127 rows x 6 columns]

# %% [markdown]
# ### Relationships between features

# %%
# Replace missing values in 'Response Code' with a specific value or NaN
logs_df['Response Code'].fillna(-1, inplace=True)  # Replace with -1 or any other value

# Convert 'Response Code' to integer
logs_df['Response Code'] = logs_df['Response Code'].astype(int)

# Plot the distribution of Response Code
sns.countplot(data=logs_df, x='Response Code')
plt.title('Distribution of Response Code')
plt.show()

# Plot the distribution of HTTP Method
sns.countplot(data=logs_df, x='HTTP Method')
plt.title('Distribution of HTTP Method')
plt.show()

# Plot the distribution of Response Size
sns.histplot(data=logs_df, x='Response Size')
plt.title('Distribution of Response Size')
plt.show()

# Plot the distribution of User-Agent
plt.figure(figsize=(12, 6))
sns.countplot(data=logs_df, y='User-Agent', order=logs_df['User-Agent'].value_counts().index[:10])
plt.title('Top 10 User-Agents')
plt.show()

# Plot the number of log entries per day
logs_df['Date'] = logs_df['Timestamp'].dt.date
daily_counts = logs_df['Date'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=daily_counts)
plt.title('Number of Log Entries per Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\darvi\AppData\Local\Temp\ipykernel_17908\4199725521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   logs_df['Response Code'].fillna(-1, inplace=True)  # Replace with -1 or any other value
# C:\Users\darvi\AppData\Local\Temp\ipykernel_17908\4199725521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   logs_df['Response Code'] = logs_df['Response Code'].astype(int)
# C:\Users\darvi\anaconda3\lib\site-packages\seaborn\distributions.py:497: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(edges, name="edges"),
# C:\Users\darvi\anaconda3\lib\site-packages\seaborn\distributions.py:498: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(widths, name="widths"),
# C:\Users\darvi\AppData\Local\Temp\ipykernel_17908\4199725521.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   logs_df['Date'] = logs_df['Timestamp'].dt.date

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Identify the variable and their types

# %%
df_types = {i: set(map(type, df[i])) for i in df.columns} 
print(df_types)

access_df_types = {i: set(map(type, access_df[i])) for i in access_df.columns} 
access_df_types
# Out:
# {'client': {<class 'str'>}, 'hostname': {<class 'str'>, <class 'float'>}, 'alias_list': {<class 'str'>}, 'address_list': {<class 'str'>, <class 'float'>}}
# {'IP Address': {str},
#  'Timestamp': {pandas._libs.tslibs.timestamps.Timestamp},
#  'HTTP Method': {str},
#  'Request URL': {str},
#  'HTTP Protocol': {str},
#  'Response Code': {numpy.int32, pandas._libs.missing.NAType},
#  'Response Size': {numpy.int32, pandas._libs.missing.NAType},
#  'User-Agent': {str},
#  'Referrer Information': {str}}

# %%
access_df.info(show_counts=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10186127 entries, 0 to 10186126
# Data columns (total 9 columns):
#  #   Column                Non-Null Count     Dtype
# ---  ------                --------------     -----
#  0   IP Address            10186127 non-null  category
#  1   Timestamp             10186127 non-null  datetime64[ns, pytz.FixedOffset(210)]
#  2   HTTP Method           10186127 non-null  category
#  3   Request URL           10186127 non-null  object
#  4   HTTP Protocol         10186127 non-null  object
#  5   Response Code         10186127 non-null  object
#  6   Response Size         10186127 non-null  object
#  7   User-Agent            10186127 non-null  object
#  8   Referrer Information  10186127 non-null  object
# dtypes: category(2), datetime64[ns, pytz.FixedOffset(210)](1), object(6)
# memory usage: 602.6+ MB

# %% [markdown]
# ### Clean data (error, remove duplicates, missing values, Outliers)

# %%
missing_values = access_df.isnull().sum().sort_values(ascending = False)
percentage_missing_values = missing_values/len(access_df)*100
check_missing_values = pd.concat([missing_values, percentage_missing_values], axis = 1, keys= ['Missing values', '% Missing'])
print(check_missing_values)
print()
# Out:
#                       Missing values  % Missing
# Response Code                    211   0.002071
# Response Size                    211   0.002071
# IP Address                         0   0.000000
# Timestamp                          0   0.000000
# HTTP Method                        0   0.000000
# Request URL                        0   0.000000
# HTTP Protocol                      0   0.000000
# User-Agent                         0   0.000000
# Referrer Information               0   0.000000

# %%
m = access_df["Response Code"].mean()
m = int(round(m))  # Round the mean value to the nearest integer
m1 = access_df["Response Size"].mean()
m1 = int(round(m1))  # Round the mean value to the nearest integer
access_df["Response Code"].fillna(m, inplace=True)
access_df["Response Size"].fillna(m1, inplace=True)
access_df.isnull().sum()
# Out:
# IP Address              0
# Timestamp               0
# HTTP Method             0
# Request URL             0
# HTTP Protocol           0
# Response Code           0
# Response Size           0
# User-Agent              0
# Referrer Information    0
# dtype: int64

# %% [markdown]
# ### Transformation (Standardization, Normalization, encoding categorical to numerical)

# %% [markdown]
# ### Data Visualization

# %%
correlation_matrix = logs_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(logs_df, vars=['Response Size', 'Response Code'])
plt.title('Pairwise Scatter Plot')
plt.show()
# Out:
# C:\Users\darvi\anaconda3\lib\site-packages\seaborn\distributions.py:497: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(edges, name="edges"),
# C:\Users\darvi\anaconda3\lib\site-packages\seaborn\distributions.py:498: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(widths, name="widths"),

# %%
sns.boxplot(data=logs_df, x='HTTP Method', y='Response Size')
plt.title('Boxplot: HTTP Method vs Response Size')
plt.show()
